# %% [markdown]
# # Recommendation using Count Vectorization

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
# Importing the necessary libraries

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../Data/Metadata.csv')

# %%
df.shape
# Out:
# (19991, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19991 entries, 0 to 19990
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 19991 non-null  int64
#  1   title              19991 non-null  object
#  2   genres             19991 non-null  object
#  3   original_language  19991 non-null  object
#  4   overview           19991 non-null  object
#  5   popularity         19991 non-null  float64
#  6   release_date       19991 non-null  object
#  7   vote_average       19991 non-null  float64
#  8   vote_count         19991 non-null  float64
#  9   keywords           19991 non-null  object
#  10  year               19991 non-null  float64
#  11  cast               19991 non-null  object
#  12  director           19991 non-null  object
#  13  score              19991 non-null  float64
# dtypes: float64(5), int64(1), object(8)
# memory usage: 2.1+ MB

# %%
df.sort_values('score', ascending=False, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'title', 'genres', 'original_language', 'overview', 'popularity',
#        'release_date', 'vote_average', 'vote_count', 'keywords', 'year',
#        'cast', 'director', 'score'],
#       dtype='object')

# %%
temp_df = df[['id','title','genres','director','cast','keywords']]

# %%
#converting the names and keyword instances into lowercase and strip all the spaces between them

temp_df.loc[:, 'cast'] = temp_df['cast'].str.lower()
temp_df.loc[:, 'genres'] = temp_df['genres'].str.lower().str.replace('-', '')
temp_df.loc[:, 'director'] = temp_df['director'].str.lower().str.replace(' ', '')

# %%
#Combine title, synopsis, and Genre
temp_df['soup'] = temp_df.apply(lambda row: f"Genres: {row['genres']}. Keywords: {row['keywords']}. Cast: {row['cast']}. Director: {row['director']}.", axis=1)
temp_df['soup'][0]
# Out:
# /var/folders/q_/sg2ykfgs57z4jr3mr195l43c0000gn/T/ipykernel_51555/74259560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['soup'] = temp_df.apply(lambda row: f"Genres: {row['genres']}. Keywords: {row['keywords']}. Cast: {row['cast']}. Director: {row['director']}.", axis=1)
# "Genres: crime comedy. Keywords: hotel newyear'seve witch bet hotelroom sperm anthology losangelescalifornia hoodlum multiplestorylines womandirector. Cast: timroth jenniferbeals antoniobanderas. Director: allisonanders\nalexandrerockwell\nrobertrodriguez\nquentintarantino."

# %%
temp_df['soup'][temp_df['id'] == 862].values[0]
# Out:
# 'Genres: animation adventure family comedy. Keywords: martialarts jealousy friendship bullying elementaryschool friends rivalry rescue mission buddy walkietalkie toycar boynextdoor newtoy neighborhood toycomestolife resourcefulness. Cast: tomhanks timallen donrickles. Director: johnlasseter.'

# %%
temp_df.drop(columns=['title', 'director', 'cast', 'genres', 'keywords'], inplace=True)
# Out:
# /var/folders/q_/sg2ykfgs57z4jr3mr195l43c0000gn/T/ipykernel_51555/440641048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df.drop(columns=['title', 'director', 'cast', 'genres', 'keywords'], inplace=True)

# %%
final_df = pd.merge(df,temp_df, left_on=['id'], right_on=['id'], how='left')

# %%
final_df.head()
# Out:
#     id                     title                       genres  \
# 0  278  The Shawshank Redemption                  Drama Crime
# 1  238             The Godfather                  Drama Crime
# 2  424          Schindler's List            Drama History War
# 3  240     The Godfather Part II                  Drama Crime
# 4  155           The Dark Knight  Drama Action Crime Thriller
#
#   original_language                                           overview  \
# 0           English  Framed in the 1940s for the double murder of h...
# 1           English  Spanning the years 1945 to 1955 a chronicle of...
# 2           English  The true story of how businessman Oskar Schind...
# 3           English  In the continuing saga of the Corleone crime f...
# 4           English  Batman raises the stakes in his war on crime. ...
#
#    popularity release_date  vote_average  vote_count  \
# 0      98.110   1994-09-23         8.702     23389.0
# 1     170.990   1972-03-14         8.695     19845.0
# 2      64.841   1993-12-15         8.572     14388.0
# 3      62.665   1974-12-20         8.598     10630.0
# 4     126.226   2008-07-16         8.513     31145.0
#
#                                             keywords    year  \
# 0  prison corruption policebrutality basedonnovel...  1994.0
# 1  basedonnovelorbook lossoflovedone loveatfirsts...  1972.0
# 2  basedonnovelorbook factory concentrationcamp h...  1993.0
# 3  italy italianamerican cuba symbolism gangster ...  1974.0
# 4  joker sadism chaos secretidentity crimefighter...  2008.0
#
#                                      cast              director     score  \
# 0      TimRobbins MorganFreeman BobGunton        Frank Darabont  8.646118
# 1         MarlonBrando AlPacino JamesCaan  Francis Ford Coppola  8.629637
# 2     LiamNeeson BenKingsley RalphFiennes      Steven Spielberg  8.487763
# 3       AlPacino RobertDuvall DianeKeaton  Francis Ford Coppola  8.484184
# 4  ChristianBale HeathLedger MichaelCaine     Christopher Nolan  8.474344
#
#                                                 soup
# 0  Genres: drama crime. Keywords: prison corrupti...
# 1  Genres: drama crime. Keywords: basedonnovelorb...
# 2  Genres: drama history war. Keywords: basedonno...
# 3  Genres: drama crime. Keywords: italy italianam...
# 4  Genres: drama action crime thriller. Keywords:...

# %% [markdown]
# ### Getting vectors from CountVectorizor

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(final_df['soup'])

# %%
count_matrix.shape
# Out:
# (19991, 51324)

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
indices = pd.Series(final_df.index, index=final_df['title'])

# %%
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title, cosine_sim = cosine_sim):

    if title not in indices:
        raise ValueError(f"Title '{title}' not found in indices")
    
    # Get the index of the movie that matches the title
    idx = indices[title]  

    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))   

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True) 

    # Get the scores of the most similar movies
    sim_scores = sim_scores[1:10 + 1]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]  

    # Getting the weighted ratings and popularity of the movies
    movies = final_df.iloc[movie_indices][['title', 'year', 'score', 'original_language', 'popularity']]

    # Sort movies first by 'Score' in descending order, then by 'popularity' in descending order
    movies = movies.sort_values(by=['score', 'popularity'], ascending=[False, False])

    return movies

# %% [markdown]
# ## Testing the setup

# %%
get_recommendations('Interstellar')
# Out:
#                   title    year     score original_language  popularity
# 270         The Martian  2015.0  7.660003           English      48.685
# 459                Moon  2009.0  7.457344           English      18.077
# 9524            Elysium  2013.0  6.489363           English      32.843
# 12620          Marooned  1969.0  6.419507           English       7.631
# 12901  Destination Moon  1950.0  6.413027           English       7.952
# 13221            JUNG_E  2023.0  6.404144            Korean     711.941
# 16085           Capsule  2015.0  6.310491           English       6.265
# 16948          Stowaway  2021.0  6.269068           English      15.621
# 17051              Love  2011.0  6.263009           English       9.394
# 18195   Lucy in the Sky  2019.0  6.172745           English      10.440

# %%
get_recommendations('Inception')
# Out:
#                                   title    year     score original_language  \
# 6500            Terror of Mechagodzilla  1975.0  6.563182          Japanese
# 12326                        Brainstorm  1983.0  6.426445           English
# 12349   Buck Rogers in the 25th Century  1979.0  6.425872           English
# 14646            Invasion: Planet Earth  2019.0  6.362298           English
# 14655  Star Wars: The Rise of Skywalker  2019.0  6.361936           English
# 16028            Moontrap: Target Earth  2017.0  6.313594           English
# 17321                       The Call Up  2016.0  6.246159           English
# 18006                     Transmorphers  2007.0  6.193359           English
# 18381  Journey 2: The Mysterious Island  2012.0  6.150550           English
# 18883                         Max Steel  2016.0  6.062716           English
#
#        popularity
# 6500       10.546
# 12326       9.253
# 12349       5.001
# 14646       6.137
# 14655      62.836
# 16028      33.402
# 17321       8.993
# 18006       4.498
# 18381      76.422
# 18883      22.236

# %%
get_recommendations('The Dark Knight Rises')
# Out:
#                                  title    year     score original_language  \
# 4                      The Dark Knight  2008.0  8.474344           English
# 262                      Batman Begins  2005.0  7.666825           English
# 1605         Batman: Assault on Arkham  2014.0  7.001524           English
# 5827   The Last Days of American Crime  2020.0  6.585388           English
# 6606                      City on Fire  1987.0  6.560384         Cantonese
# 8073               Across 110th Street  1972.0  6.521387           English
# 8991                              NH10  2015.0  6.500675             Hindi
# 11810                         Defendor  2009.0  6.437744           English
# 13233                       Kick-Ass 2  2013.0  6.403846           English
# 16183                      The Courier  2019.0  6.306215           English
#
#        popularity
# 4         126.226
# 262        93.893
# 1605       14.829
# 5827       14.945
# 6606       10.057
# 8073        7.078
# 8991        4.279
# 11810       9.129
# 13233      31.942
# 16183      22.071

# %%
get_recommendations('Hulk')
# Out:
#                                                title    year     score  \
# 1519                                       Injustice  2021.0  7.024843
# 1749                                           X-Men  2000.0  6.963155
# 6953                                   Hulk vs. Thor  2009.0  6.550188
# 9475                      Hulk: Where Monsters Dwell  2016.0  6.490451
# 11214                                         Krrish  2006.0  6.451521
# 12328  Avengers Confidential: Black Widow & Punisher  2014.0  6.426286
# 12329                     Superman: Brainiac Attacks  2006.0  6.426267
# 17716                            The Incredible Hulk  2008.0  6.218239
# 19545                                          Steel  1997.0  5.867048
# 19988                                 Batman & Robin  1997.0  4.544024
#
#       original_language  popularity
# 1519            English      45.986
# 1749            English       1.423
# 6953            English      12.939
# 9475            English       8.846
# 11214             Hindi       7.992
# 12328          Japanese      37.412
# 12329           English       9.532
# 17716           English      59.440
# 19545           English      12.966
# 19988           English      36.578

# %%
get_recommendations('Your Name')
# Out:
#                                                  title    year     score  \
# 2248                           The Anthem of the Heart  2015.0  6.863976
# 2377                    Children Who Chase Lost Voices  2011.0  6.843095
# 4397                             I've Always Liked You  2016.0  6.648975
# 4429                       The Moment You Fall in Love  2016.0  6.647458
# 4861                                     Until Forever  2016.0  6.625323
# 6114                                    Orange: Future  2016.0  6.575597
# 6891                                      Her Blue Sky  2019.0  6.551745
# 7231   Love, Chunibyo & Other Delusions! Rikka Version  2013.0  6.542290
# 7479                                  The Lost Husband  2020.0  6.535928
# 10982                                           Midori  1992.0  6.456913
#
#       original_language  popularity
# 2248           Japanese      25.317
# 2377           Japanese      24.701
# 4397           Japanese      21.744
# 4429           Japanese      22.387
# 4861            English      22.492
# 6114           Japanese       5.132
# 6891           Japanese      20.975
# 7231           Japanese      15.995
# 7479            English       8.044
# 10982          Japanese      19.336

# %%
get_recommendations('The Godfather')
# Out:
#                                  title    year     score original_language  \
# 3                The Godfather Part II  1974.0  8.484184           English
# 425                       The Irishman  2019.0  7.495517           English
# 703             The Godfather Part III  1990.0  7.306118           English
# 1910  The Godfather Trilogy: 1901-1980  1992.0  6.927905           English
# 3349            Shoot the Piano Player  1960.0  6.728088            French
# 4661                          Piranhas  2019.0  6.635774           Italian
# 5289                Salvatore Giuliano  1962.0  6.605344           Italian
# 5808               Gangubai Kathiawadi  2022.0  6.585808             Hindi
# 6368                    The Banishment  2008.0  6.567257           Russian
# 8812                       The Gambler  1974.0  6.504228           English
#
#       popularity
# 3         62.665
# 425       27.739
# 703       67.934
# 1910      11.684
# 3349       9.386
# 4661      10.606
# 5289       5.686
# 5808      10.512
# 6368       5.719
# 8812       8.158

# %%
get_recommendations('Suzume')
# Out:
#                                                   title    year     score  \
# 2377                     Children Who Chase Lost Voices  2011.0  6.843095
# 2684                            One Piece: Strong World  2009.0  6.804882
# 3062       Naruto Shippuden the Movie: The Will of Fire  2009.0  6.758979
# 3131                                      Drifting Home  2022.0  6.751755
# 3950  Inuyasha the Movie 2: The Castle Beyond the Lo...  2002.0  6.677386
# 4922    Inuyasha the Movie 4: Fire on the Mystic Island  2004.0  6.622518
# 8352      Pokémon the Movie: White - Victini and Zekrom  2011.0  6.514447
# 8482     Naruto the Movie: Legend of the Stone of Gelel  2005.0  6.511735
# 8528    Pokémon the Movie: Black - Victini and Reshiram  2011.0  6.510666
# 8696                                      Modest Heroes  2018.0  6.506988
#
#      original_language  popularity
# 2377          Japanese      24.701
# 2684          Japanese      31.282
# 3062          Japanese      47.101
# 3131          Japanese     126.618
# 3950          Japanese      26.874
# 4922          Japanese      28.915
# 8352          Japanese      13.737
# 8482          Japanese      34.361
# 8528          Japanese      14.226
# 8696          Japanese      25.804

# %% [markdown]
# Now we have implemented the Count Vectorizer on the Metadata.csv, in the next we will dealing xgboost for recommandation
